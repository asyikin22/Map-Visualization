# %% [markdown]
# # Objective
# - Produce a folium map in a python app based on a csv data: **EV charging stations**
#
# - read CSV data with Python
#
# - Transform/clean data into correct format
#
# - create folium map displaying information
#
# **Links**:
# - Dataset: https://catalog.data.gov/dataset/electric-vehicle-charging-stations
#
# - Folium: https://python-visualization.github.io/folium/latest/
#
# - github: https://github.com/python-visualization/folium

# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\ASYIKIN\OneDrive\Desktop\Map Viz\Python + Folium\Electric_Vehicle_Charging_Stations.csv')

df.head()
# Out:
#                           Station Name          Street Address          City  \
# 0                        BMW OF DARIEN        138-142 Ledge Rd        Darien
# 1         Dunkin’ - Tesla Supercharger           893 E Main St       Meriden
# 2  Town of Beacon Falls - Commuter Lot           105 N Main St  Beacon Falls
# 3                      OLD SAYBROOK VW  319 Middlesex Turnpike  Old Saybrook
# 4               Fairfield Rail Station        80 Mill Plain Rd     Fairfield
#
#                      Access Days Time EV Level1 EVSE Num EV Level2 EVSE Num  \
# 0                      24 hours daily               NONE                  2
# 1  24 hours daily; for Tesla use only               NONE               NONE
# 2                      24 hours daily               NONE                  1
# 3                      24 hours daily               NONE                  2
# 4                      24 hours daily               NONE                  2
#
#   EV DC Fast Count EV Other Info              New Georeferenced Column
# 0             NONE          NONE         POINT (-73.4764687 41.072882)
# 1                8          NONE          POINT (-72.773473 41.527367)
# 2             NONE          NONE  POINT (-73.065583 41.44548100000001)
# 3             NONE          NONE           POINT (-72.3825 41.3102778)
# 4             NONE          NONE          POINT (-73.264511 41.143125)

# %%
df.columns
# Out:
# Index(['Station Name', 'Street Address', 'City', 'Access Days Time',
#        'EV Level1 EVSE Num', 'EV Level2 EVSE Num', 'EV DC Fast Count',
#        'EV Other Info', 'New Georeferenced Column'],
#       dtype='object')

# %%
# select two columns only and create new data frame to reflect it

df2=df[['Station Name', 'New Georeferenced Column']]

print(df2.columns)
print(df2.head())
# Out:
# Index(['Station Name', 'New Georeferenced Column'], dtype='object')
#                           Station Name              New Georeferenced Column
# 0                        BMW OF DARIEN         POINT (-73.4764687 41.072882)
# 1         Dunkin’ - Tesla Supercharger          POINT (-72.773473 41.527367)
# 2  Town of Beacon Falls - Commuter Lot  POINT (-73.065583 41.44548100000001)
# 3                      OLD SAYBROOK VW           POINT (-72.3825 41.3102778)
# 4               Fairfield Rail Station          POINT (-73.264511 41.143125)

# %%
# select the coordinate and split it into two, separate by commas
df2.iloc[0, 1]
# Out:
# 'POINT (-73.4764687 41.072882)'

# %% [markdown]
# # Extract the latitude and longitude and assign them into new columns

# %%
#define a function to extract coordinates
def extract_coord(coord_str):
    coord_str = coord_str.replace('POINT (', '').replace(')', '')
    longitude, latitude = coord_str.split()
    return float(longitude), float(latitude)

#apply the function to each row
df2[['Longitude', 'Latitude']] = df2['New Georeferenced Column'].apply(lambda x: pd.Series(extract_coord(x)))

df2
# Out:
# C:\Users\ASYIKIN\AppData\Local\Temp\ipykernel_9948\1763010807.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2[['Longitude', 'Latitude']] = df2['New Georeferenced Column'].apply(lambda x: pd.Series(extract_coord(x)))
# C:\Users\ASYIKIN\AppData\Local\Temp\ipykernel_9948\1763010807.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2[['Longitude', 'Latitude']] = df2['New Georeferenced Column'].apply(lambda x: pd.Series(extract_coord(x)))
#                                           Station Name  \
# 0                                        BMW OF DARIEN
# 1                         Dunkin’ - Tesla Supercharger
# 2                  Town of Beacon Falls - Commuter Lot
# 3                                      OLD SAYBROOK VW
# 4                               Fairfield Rail Station
# ..                                                 ...
# 380                  Lee Partyka Chevrolet Mazda Isuzu
# 381                                        777 MAIN ST
# 382                           Norwich Public Utilities
# 383                                    Fairfield Plaza
# 384  Eastern Connecticut State University - Shakesp...
#
#                  New Georeferenced Column  Longitude   Latitude
# 0           POINT (-73.4764687 41.072882) -73.476469  41.072882
# 1            POINT (-72.773473 41.527367) -72.773473  41.527367
# 2    POINT (-73.065583 41.44548100000001) -73.065583  41.445481
# 3             POINT (-72.3825 41.3102778) -72.382500  41.310278
# 4            POINT (-73.264511 41.143125) -73.264511  41.143125
# ..                                    ...        ...        ...
# 380        POINT (-72.9100121 41.3729709) -72.910012  41.372971
# 381          POINT (-72.674468 41.766676) -72.674468  41.766676
# 382  POINT (-72.063516 41.52757900000001) -72.063516  41.527579
# 383            POINT (-73.41763 41.55735) -73.417630  41.557350
# 384         POINT (-72.208134 41.7385909) -72.208134  41.738591
#
# [385 rows x 4 columns]

# %% [markdown]
# # Using folium
#
# - install folium in the terminal - pip install folium
#
# - import folium
#
# - I had trouble importing it on Jupyter. Solution from stack overflow:
#     - https://stackoverflow.com/a/45771035/23241868
#
# - Folium won't run on jupy notebook. Solution from chatgpt:
#     - Ensure folium is installed in anaconda environment
#     - Anaconda prompt
#         * Activate environment: conda active base
#         * install folium: conda install -c conda-forge folium
#
#     - Verify installation in Jupy notebook
#         * import folium and check its version = 0.17.0 (This is the correct version)
#
#     - It works! I'm a genius lol 🥳🥳🥳
#
#
# # Manually create Marker on map

# %%
# import sys
# print(sys.executable)

import folium
print(folium.__version__)

# Create a map object centered around specific latitude and longitude
m = folium.Map(location=[3.15894, 101.6952656], titles="cartodb positron", zoom_start=11)

# Adding Marker
folium.Marker(
    location=[3.1379057,101.6844585],
    tooltip='Click me!',
    popup='Muzium Negara'
).add_to(m)

folium.Marker(
    location=[2.9419418,101.6685103],
    tooltip='Click me!',
    popup='Putrajaya Lake'
).add_to(m)

folium.Marker(
    location=[2.9774314,101.3323699],
    tooltip='Click me!',
    popup='Port Klang'
).add_to(m)

# Display the map
m
# Out:
# 0.17.0
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b85e8213936278b230de5d7429b07084 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b85e8213936278b230de5d7429b07084&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b85e8213936278b230de5d7429b07084 = L.map(
#                 &quot;map_b85e8213936278b230de5d7429b07084&quot;,
#                 {
#                     center: [3.15894, 101.6952656],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     titles: &quot;cartodb positron&quot;,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_183f28aec9334b4e9648a481ecffc421 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_183f28aec9334b4e9648a481ecffc421.addTo(map_b85e8213936278b230de5d7429b07084);
#
#
#             var marker_1843cd1374c81c73cfdd824f62573814 = L.marker(
#                 [3.1379057, 101.6844585],
#                 {}
#             ).addTo(map_b85e8213936278b230de5d7429b07084);
#
#
#         var popup_836492c3488767917d55c7e05d2d5462 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_eed4492af2f11c2b5438741b655831c0 = $(`&lt;div id=&quot;html_eed4492af2f11c2b5438741b655831c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Muzium Negara&lt;/div&gt;`)[0];
#                 popup_836492c3488767917d55c7e05d2d5462.setContent(html_eed4492af2f11c2b5438741b655831c0);
#
#
#
#         marker_1843cd1374c81c73cfdd824f62573814.bindPopup(popup_836492c3488767917d55c7e05d2d5462)
#         ;
#
#
#
#
#             marker_1843cd1374c81c73cfdd824f62573814.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_074dc94eac5551b496494f2a999830b6 = L.marker(
#                 [2.9419418, 101.6685103],
#                 {}
#             ).addTo(map_b85e8213936278b230de5d7429b07084);
#
#
#         var popup_08086cb667dff8472745cd1a17f32c9a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_06278fae63f9521fbcb372d65883cddb = $(`&lt;div id=&quot;html_06278fae63f9521fbcb372d65883cddb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Putrajaya Lake&lt;/div&gt;`)[0];
#                 popup_08086cb667dff8472745cd1a17f32c9a.setContent(html_06278fae63f9521fbcb372d65883cddb);
#
#
#
#         marker_074dc94eac5551b496494f2a999830b6.bindPopup(popup_08086cb667dff8472745cd1a17f32c9a)
#         ;
#
#
#
#
#             marker_074dc94eac5551b496494f2a999830b6.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b2cbe90d91e245f724c5b0f03690846c = L.marker(
#                 [2.9774314, 101.3323699],
#                 {}
#             ).addTo(map_b85e8213936278b230de5d7429b07084);
#
#
#         var popup_d1219edacf9183e770257596dcbbe50c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f22f09608450b5280adced66bf1667e3 = $(`&lt;div id=&quot;html_f22f09608450b5280adced66bf1667e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Port Klang&lt;/div&gt;`)[0];
#                 popup_d1219edacf9183e770257596dcbbe50c.setContent(html_f22f09608450b5280adced66bf1667e3);
#
#
#
#         marker_b2cbe90d91e245f724c5b0f03690846c.bindPopup(popup_d1219edacf9183e770257596dcbbe50c)
#         ;
#
#
#
#
#             marker_b2cbe90d91e245f724c5b0f03690846c.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Extract longitude and latitude from DF and apply marker on maps
#
# - mean method
#     * We use mean() to get the average latitude and longitude and pass these values to 'location' for centering the map
#
# - manually specify a central point for the map
#     * This defines the point where the map will be centered

# %%
df2.columns
# Out:
# Index(['Station Name', 'New Georeferenced Column', 'Longitude', 'Latitude'], dtype='object')

# %%
#Using mean method

# map1 = folium.Map(location=[df2['Latitude'].mean(), df2['Longitude'].mean()], zoom_start=9.45)
# for idx, row in df2.iterrows():
#     folium.Marker(
#         location=[row['Latitude'], row['Longitude']],
#         popup=row['Station Name'],
#         tooltip='Click me!'
#     ).add_to(map1)

# map1

# manually specify a central point for the map
central_location = [41.5025,-72.699997]

# Create a folium map centered at the location
map1 = folium.Map(location=central_location, zoom_start=9)

#add markers for each station
for idx, row in df2.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=row['Station Name'],
        tooltip='Click me!'
    ).add_to(map1)

map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b269fa9e96f9dcb785ec4ff97c0ef2c5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b269fa9e96f9dcb785ec4ff97c0ef2c5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b269fa9e96f9dcb785ec4ff97c0ef2c5 = L.map(
#                 &quot;map_b269fa9e96f9dcb785ec4ff97c0ef2c5&quot;,
#                 {
#                     center: [41.5025, -72.699997],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_12da7f65b3b0cf6b1b967bc6d5d0c16b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_12da7f65b3b0cf6b1b967bc6d5d0c16b.addTo(map_b269fa9e96f9dcb785ec4ff97c0ef2c5);
#
#
#             var marker_beb0125b4c3fd0f92d9aa9686f8bf096 = L.marker(
#                 [41.072882, -73.4764687],
#                 {}
#             ).addTo(map_b269fa9e96f9dcb785ec4ff97c0ef2c5);
#
#
#         var popup_72745b4f4fe0f5f892f4ae13c23a865a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f92c33c50e6e46c319e333339d0c94dc = $(`&lt;div id=&quot;html_f92c33c50e6e46c319e333339d0c94dc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BMW OF DARIEN&lt;/div&gt;`)[0];
#                 popup_72745b4f4fe0f5f892f4ae13c23a865a.setContent(html_f92c33c50e6e46c319e333339d0c94dc);
#
#
#
#         marker_beb0125b4c3fd0f92d9aa9686f8bf096.bindPopup(popup_72745b4f4fe0f5f892f4ae13c23a865a)
#         ;
#
#
#
#
#             marker_beb0125b4c3fd0f92d9aa9686f8bf096.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3c672285fbe86c5226aecc772c034df8 = L.marker(
#                 [41.527367, -72.773473],
#                 {}
#             ).addTo(map_b269fa9e96f9dcb785ec4ff97c0ef2c5);
#
#
#         var popup_b609eb49d816f1aae9fd478f43add924 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_95fab36dce2a0f6158d79e990924c3e9 = $(`&lt;div id=&quot;html_95fab36dce2a0f6158d79e990924c3e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dunkin’ - Tesla Supercharger&lt;/div&gt;`)[0];
#                 popup_b609eb49d816f1aae9fd478f43add924.setContent(html_95fab36dce2a0f6158d79e990924c3e9);
#
#
#
#         marker_3c672285fbe86c5226aecc772c034df8.bindPopup(popup_b609eb49d816f1aae9fd478f43add924)
#         ;
#
#
#
#
#             marker_3c672285fbe86c5226aecc772c034df8.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6fc87c04ec3b2691509a6d39086a229f = L.marker(
#                 [41.44548100000001, -73.065583],
#                 {}
#             ).addTo(map_b269fa9e96f9dcb785ec4ff97c0ef2c5);
#
#
#         var popup_32ef274604d6baceea2f47bf0f747cac = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_652f3c12da81004e8c578df2b461baba = $(`&lt;div id=&quot;html_652f3c12da81004e8c578df2b461baba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Town of Beacon Falls - Commuter Lot&lt;/div&gt;`)[0];
#                 popup_32ef274604d6baceea2f47bf0f747cac.setContent(html_652f3c12da81004e8c578df2b461baba);
#
#
#
#         marker_6fc87c04ec3b2691509a6d39086a229f.bindPopup(popup_32ef274604d6baceea2f47bf0f747cac)
#         ;
#
#
#
#
#             marker_6fc87c04ec3b2691509a6d39086a229f.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_91042049a9a44674bbcffc74d2d4739e = L.marker(
#                 [41.3102778, -72.3825],
#                 {}
#             ).addTo(map_b269fa9e96f9dcb785ec4ff97c0ef2c5);
#
#
#         var popup_3a7079cd2673960f10348d8adb0aae30 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6c9262f4f75a270f5a51e0084162ddb5 = $(`&lt;div id=&quot;html_6c9262f4f75a270f5a51e0084162ddb5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;OLD SAYBROOK VW&lt;/div&gt;`)[0];
#                 popup_3a7079cd2673960f10348d8adb0aae30.setContent(html_6c9262f4f75a270f5a51e0084162ddb5);
#
#
#
#         marker_91042049a9a44674bbcffc74d2d4739e.bindPopup(popup_3a7079cd2673960f10348d8adb0aae30)
#         ;
#
#
#
#
#             marker_91042049a9a44674bbcffc74d2d4739e.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );

# %% [markdown]
# # Clustering Markers with the FastMarkerCluster
#
# - https://python-visualization.github.io/folium/latest/user_guide/plugins/marker_cluster.html#FastMarkerCluster
#
# - this plugin allows for efficient clustering of markers on a map

# %%
from folium.plugins import FastMarkerCluster

# manually specify a central point for the map
central_location = [41.5025,-72.699997]

# Create a folium map centered at the location
map2 = folium.Map(location=central_location, zoom_start=9.3)

#extract latitude and longitude from dataframe
latitudes = df2['Latitude'].tolist()
longitudes = df2['Longitude'].tolist()

#create list of tuples (lat, long)
locations = list(zip(latitudes, longitudes))

FastMarkerCluster(data=locations).add_to(map2)

map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a92de686f8c95e3179dc4cb6d1351a76 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a92de686f8c95e3179dc4cb6d1351a76&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a92de686f8c95e3179dc4cb6d1351a76 = L.map(
#                 &quot;map_a92de686f8c95e3179dc4cb6d1351a76&quot;,
#                 {
#                     center: [41.5025, -72.699997],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9.3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_22bd2f709cd2828c2c0d1cdf436a9b73 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_22bd2f709cd2828c2c0d1cdf436a9b73.addTo(map_a92de686f8c95e3179dc4cb6d1351a76);
#
#
#             var fast_marker_cluster_cd22add45cca906da2d7fb0496d2b3f1 = (function(){
#
#                 var callback = function (row) {
#                     var icon = L.AwesomeMarkers.icon();
#                     var marker = L.marker(new L.LatLng(row[0], row[1]));
#                     marker.setIcon(icon);
#                     return marker;
#                 };
#
#                 var data = [[41.072882, -73.4764687], [41.527367, -72.773473], [41.44548100000001, -73.065583], [41.3102778, -72.3825], [41.143125, -73.264511], [41.525611, -72.0741188], [41.722672, -72.759717], [41.711717, -72.6086744], [41.072919, -73.476189], [41.365973, -72.026147], [41.550922, -73.025659], [41.730405, -72.79061800000001], [41.299792, -73.106051], [41.4618954, -72.8231924], [41.650999, -72.679679], [41.078282, -73.466318], [41.297487000000004, -72.926722], [41.251966, -73.297822], [41.80452, -72.562282], [41.988528, -73.138786], [41.37356200000001, -71.961361], [41.929342, -72.670609], [41.811817, -72.261825], [41.263416, -72.560456], [41.649365, -72.770648], [41.768396, -72.195701], [41.8750604, -73.1049768], [41.7640244, -73.070231], [41.317722, -72.065994], [41.5871612, -72.6824246], [41.176442, -73.230597], [41.728247, -72.188445], [41.28006, -72.43786], [41.353572, -72.870574], [41.2975353, -72.9270748], [41.803497, -73.12122300000001], [41.699374, -72.894672], [41.296212, -72.781436], [41.800421, -72.242231], [41.814316, -72.507845], [41.536236, -72.797226], [41.306474, -72.948514], [41.537218, -72.796702], [41.664356600000005, -72.7788286], [41.287164, -72.657682], [41.549361, -73.02614], [41.983904, -72.489406], [41.765434, -72.684758], [41.563917, -72.711926], [41.467376, -72.817586], [41.766656, -72.676489], [41.198568, -73.132624], [41.331744, -71.906918], [41.145215689458, -73.35947443366], [41.0409048, -73.5318605], [41.202742, -73.117486], [41.53713, -73.005613], [41.354043, -72.211435], [41.692973, -72.762739], [41.5785572, -73.41116], [41.203858, -73.271401], [41.054155, -73.541625], [41.4007757, -73.2847962], [41.050574, -73.53779], [41.765034, -72.701271], [41.8298475, -72.7373929], [41.628033, -73.3124], [41.8041965, -72.2442218], [41.4168397, -72.8415278], [41.953668, -72.303231], [41.742975, -72.722829], [41.6972, -72.7214], [41.162306, -73.267585], [41.763287, -72.670165], [41.104791, -73.418883], [41.327848, -72.960178], [41.465044, -73.230644], [41.282264, -73.492605], [41.539218, -72.802667], [41.138623, -73.317072], [41.4733521, -71.9600027], [41.7660404, -72.6446905], [41.4733358, -71.9600034], [41.6659341, -72.8580302], [41.067306, -73.504917], [41.157925, -73.240315], [41.094294, -73.709755], [41.27077, -72.608573], [41.65514, -72.729203], [41.289894, -72.809324], [41.714088, -72.608292], [41.054321, -73.516045], [41.784487, -72.7479436], [41.355486, -72.093784], [41.238119, -73.036133], [41.795898, -72.552974], [41.370726, -72.119376], [41.6717114, -72.8670212999999], [41.308741, -72.932698], [41.764376, -72.668833], [41.723169, -72.214432], [41.29434, -73.11066], [41.3777667, -73.475576], [41.2904885216395, -72.5804966772461], [41.811022, -72.923177], [41.2974027, -72.9263108], [41.472228, -72.6809263], [41.146162, -73.245943], [41.185685, -73.234423], [41.763294, -72.678633], [41.759108000000005, -72.744596], [41.596225, -72.877465], [41.053776, -73.5160406], [41.167407, -73.233711], [41.465514, -73.487032], [41.2645, -73.004741], [41.307602, -72.968506], [41.070243, -73.4948097], [41.305071, -72.756902], [41.331117, -73.472615], [41.28648200000001, -72.416634], [41.138478, -73.314364], [41.190701, -73.166282], [41.956727, -72.289249], [41.767185, -72.670032], [41.780058, -72.312334], [41.198467, -73.131808], [41.
